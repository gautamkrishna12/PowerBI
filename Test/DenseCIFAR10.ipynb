# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Input,Flatten
from tensorflow.keras.utils import to_categorical

(X_train,y_train),(X_test,y_test)=cifar10.load_data()
X_train=X_train/255
X_test=X_test/255
y_train_cat=to_categorical(y_train,num_classes=10)
y_test_cat=to_categorical(y_test,num_classes=10)

model=Sequential()
model.add(Input(shape=(32,32,3)))
model.add(Flatten())
model.add(Dense(units=512,activation='relu'))
model.add(Dense(units=256,activation='relu'))
model.add(Dense(units=128,activation='relu'))
model.add(Dense(units=10,activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

model.fit(X_train,y_train_cat,epochs=5,batch_size=62,validation_split=0.2)

loss,acc=model.evaluate(X_test,y_test_cat)
print(f"\nAccuracy: {round(acc,3)}")
print(f"Loss : {round(loss,3)}")


class_labels=['Airplane','Automobile','Bird','Cat','Deer','Dog','Frog','Horse','Ship','Truck']
for i in range(3):
    plt.figure(figsize=(5,3))
    plt.subplot(1,2,1)
    plt.imshow(X_test[i])
    plt.subplot(1,2,2)
    pred=model.predict(X_test[i].reshape(1,32,32,3))
    plt.barh(class_labels,pred[0])
    plt.tight_layout()
    plt.show()
# Out:
# Epoch 1/5
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 14s 17ms/step - accuracy: 0.2553 - loss: 2.0354 - val_accuracy: 0.3448 - val_loss: 1.7928
# Epoch 2/5
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.3782 - loss: 1.7252 - val_accuracy: 0.3855 - val_loss: 1.7162
# Epoch 3/5
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4145 - loss: 1.6365 - val_accuracy: 0.4245 - val_loss: 1.6195
# Epoch 4/5
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.4406 - loss: 1.5626 - val_accuracy: 0.4282 - val_loss: 1.6020
# Epoch 5/5
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.4550 - loss: 1.5145 - val_accuracy: 0.4414 - val_loss: 1.5744
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.4502 - loss: 1.5387
#
# Accuracy: 0.45
# Loss : 1.54
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Input,Flatten
from tensorflow.keras.utils import to_categorical

(X_train,y_train),(X_test,y_test)=cifar10.load_data()
X_train=X_train/255
X_test=X_test/255
y_train_cat=to_categorical(y_train,num_classes=10)
y_test_cat=to_categorical(y_test,num_classes=10)

model=Sequential()
model.add(Input(shape=(32,32,3)))
model.add(Flatten())
model.add(Dense(units=512,activation='relu'))
model.add(Dense(units=256,activation='relu'))
model.add(Dense(units=128,activation='relu'))
model.add(Dense(units=10,activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

model.fit(X_train,y_train_cat,epochs=5,batch_size=62,validation_split=0.2)

loss,acc=model.evaluate(X_test,y_test_cat)
print(f"\nAccuracy: {round(acc,3)}")
print(f"Loss : {round(loss,3)}")


class_labels=['Airplane','Automobile','Bird','Cat','Deer','Dog','Frog','Horse','Ship','Truck']
for i in range(3):
    plt.figure(figsize=(5,3))
    plt.subplot(1,2,1)
    plt.imshow(X_test[i])
    plt.subplot(1,2,2)
    pred=model.predict(X_test[i].reshape(1,32,32,3))
    plt.barh(class_labels,pred[0])
    plt.tight_layout()
    plt.show()
# Out:
# Epoch 1/5
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.2673 - loss: 2.0346 - val_accuracy: 0.3627 - val_loss: 1.7884
# Epoch 2/5
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.3818 - loss: 1.7139 - val_accuracy: 0.3824 - val_loss: 1.7085
# Epoch 3/5
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.4105 - loss: 1.6441 - val_accuracy: 0.4255 - val_loss: 1.6230
# Epoch 4/5
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.4375 - loss: 1.5603 - val_accuracy: 0.4296 - val_loss: 1.5926
# Epoch 5/5
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.4585 - loss: 1.5207 - val_accuracy: 0.4272 - val_loss: 1.6174
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4369 - loss: 1.5861
#
# Accuracy: 0.435
# Loss : 1.586
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
